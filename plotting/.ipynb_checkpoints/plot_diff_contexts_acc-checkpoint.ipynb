# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = '~/Google Drive/Project/'
df0 = pd.read_csv(path+'attention/csv/diff_contexts_definition.csv', index_col=0)
df0
# Out:
#                                                 wnids  num_examples  \
# 0   ['n11939491', 'n13044778', 'n12057211', 'n0202...          2416
# 1   ['n02606052', 'n01518878', 'n03888257', 'n0238...          2422
# 2   ['n12267677', 'n02422106', 'n02417914', 'n0433...          2416
# 3   ['n02128757', 'n02447366', 'n01531178', 'n0248...          2445
# 4   ['n02110806', 'n02074367', 'n02051845', 'n0170...          2393
# 5   ['n07714571', 'n01917289', 'n03447447', 'n0149...          2400
# 6   ['n02101006', 'n03617480', 'n02494079', 'n0209...          2431
# 7   ['n03976467', 'n04399382', 'n02422699', 'n0946...          2402
# 8   ['n02027492', 'n02113799', 'n02490219', 'n0769...          2400
# 9   ['n02791124', 'n01608432', 'n02325366', 'n0393...          2435
# 10  ['n02268443', 'n04204347', 'n01784675', 'n0151...          2397
# 11  ['n03786901', 'n10148035', 'n03085013', 'n0149...          2416
# 12  ['n02128925', 'n04372370', 'n03838899', 'n0280...          2404
# 13  ['n04423845', 'n03388183', 'n01883070', 'n0402...          2443
# 14  ['n02109047', 'n02089867', 'n02106030', 'n0436...          2404
# 15  ['n02971356', 'n02167151', 'n07892512', 'n0299...          2402
# 16  ['n02443484', 'n03709823', 'n03179701', 'n0295...          2408
# 17  ['n07579787', 'n02783161', 'n04033995', 'n0450...          2396
# 18  ['n03110669', 'n04263257', 'n03868863', 'n0375...          2400
# 19  ['n02895154', 'n02107908', 'n02769748', 'n0274...          2408
#
#     num_correct  incontext_acc  outofcontext_acc
# 0          2279       0.943295          0.630854
# 1          2171       0.896367          0.633294
# 2          2067       0.855546          0.635481
# 3          2024       0.827812          0.636822
# 4          1912       0.798997          0.638543
# 5          1858       0.774167          0.639818
# 6          1822       0.749486          0.641037
# 7          1742       0.725229          0.642377
# 8          1675       0.697917          0.643811
# 9          1638       0.672690          0.645111
# 10         1558       0.649979          0.646321
# 11         1502       0.621689          0.647811
# 12         1437       0.597754          0.649060
# 13         1398       0.572247          0.650464
# 14         1308       0.544093          0.651874
# 15         1217       0.506661          0.653831
# 16         1136       0.471761          0.655684
# 17         1034       0.431553          0.657737
# 18          866       0.360833          0.661460
# 19          542       0.225083          0.668645

# %%
df1 = pd.read_csv(path+'attention/csv/diff_contexts_trained_acc.csv', index_col=0)
df1
# Out:
#     incontext_loss  incontext_acc  incontext_top_k_categorical_accuracy  \
# 0         0.295810       0.945364                              0.977235
# 1         0.440089       0.902560                              0.964905
# 2         0.610536       0.860513                              0.947020
# 3         0.644338       0.851125                              0.944785
# 4         0.832869       0.810698                              0.928542
# 5         0.833688       0.801667                              0.922917
# 6         0.936638       0.774578                              0.914850
# 7         1.069519       0.740633                              0.908410
# 8         1.201649       0.719583                              0.884583
# 9         1.189595       0.697741                              0.898563
# 10        1.384098       0.678348                              0.869837
# 11        1.252864       0.710679                              0.887003
# 12        1.486410       0.626872                              0.873128
# 13        1.677600       0.597217                              0.835448
# 14        1.646627       0.594426                              0.853577
# 15        1.850736       0.545379                              0.823064
# 16        2.106034       0.512043                              0.802326
# 17        1.959873       0.491653                              0.816778
# 18        2.632919       0.378333                              0.714167
# 19        2.868369       0.259136                              0.694767
#
#     outofcontext_loss  outofcontext_acc  \
# 0            1.555920          0.630808
# 1            1.548336          0.632572
# 2            1.537564          0.634963
# 3            1.538662          0.635266
# 4            1.519773          0.638745
# 5            1.523829          0.638702
# 6            1.511889          0.640234
# 7            1.507650          0.641647
# 8            1.493637          0.643853
# 9            1.492713          0.645509
# 10           1.488351          0.645714
# 11           1.514795          0.639987
# 12           1.479378          0.648506
# 13           1.464383          0.649830
# 14           1.472645          0.649378
# 15           1.454999          0.652626
# 16           1.443222          0.655018
# 17           1.435096          0.657868
# 18           1.415128          0.661658
# 19           1.391401          0.668921
#
#     outofcontext_top_k_categorical_accuracy  alldata_loss  alldata_acc  \
# 0                                  0.851078      1.491493     0.646876
# 1                                  0.851595      1.491496     0.646420
# 2                                  0.852537      1.489797     0.646586
# 3                                  0.852928      1.492434     0.646420
# 4                                  0.854211      1.484036     0.647684
# 5                                  0.853701      1.487934     0.647187
# 6                                  0.855139      1.481663     0.647311
# 7                                  0.855045      1.484337     0.646938
# 8                                  0.857046      1.477672     0.647975
# 9                                  0.856696      1.476107     0.648472
# 10                                 0.857042      1.481771     0.647684
# 11                                 0.854298      1.500294     0.643870
# 12                                 0.857300      1.478352     0.647767
# 13                                 0.859824      1.473579     0.647560
# 14                                 0.858028      1.480012     0.646959
# 15                                 0.860682      1.473435     0.647601
# 16                                 0.861529      1.474989     0.648203
# 17                                 0.862548      1.460040     0.649882
# 18                                 0.866167      1.474653     0.647830
# 19                                 0.868215      1.463915     0.648762
#
#     alldata_top_k_categorical_accuracy
# 0                             0.857540
# 1                             0.857415
# 2                             0.857415
# 3                             0.857685
# 4                             0.858079
# 5                             0.857312
# 6                             0.858286
# 7                             0.857871
# 8                             0.858576
# 9                             0.858949
# 10                            0.857830
# 11                            0.856089
# 12                            0.858245
# 13                            0.858763
# 14                            0.857954
# 15                            0.858949
# 16                            0.858721
# 17                            0.860401
# 18                            0.858721
# 19                            0.859696

# %%
plt.plot(df0[])

# %%
# plt.figure(figsize=(10, 6))
fig, ax = plt.subplots()
plt.plot(df0['incontext_acc'], '-', label='in context (base)')
plt.plot(df0['outofcontext_acc'], '-', label='out of context (base)')
plt.plot(df1['incontext_acc'], '--', label='in context (attention)')
plt.plot(df1['outofcontext_acc'], '--', label='out of context (attention)')
# plt.plot(df1['alldata_acc'], '--', label='all data (attention)')
# plt.plot(range(20), [np.sum(df0['num_correct'])/np.sum(df0['num_examples']) for _ in range(20)])
plt.xlabel('Training context')
plt.ylabel('Top-1 accuracy')
plt.xticks((0, 19))
ax.set_xticklabels((1, 20))
plt.legend(title='Source of test examples')
plt.savefig('diff_contexts_acc.png', dpi=600)
plt.show()

# %%
fig, ax = plt.subplots()
change_incontext = df1['incontext_acc']-df0['incontext_acc']
change_outofcontext = df1['outofcontext_acc']-df0['outofcontext_acc']
x = np.arange(20)
w = 0.4
plt.bar(x-w/2, change_incontext, width=w, label='in context')
plt.bar(x+w/2, change_outofcontext, width=w, label='out of context')
plt.xlabel('Training context')
plt.ylabel('Change in top-1 accuracy')
plt.ylim((-0.01, 0.09))
plt.xticks((0, 19))
# plt.yticks(range(-0.01, 0.09, 0.01))
ax.set_xticklabels((1, 20))
plt.legend(title='Source of test examples')
# plt.savefig('diff_contexts_acc_change.png', dpi=600)
plt.show()
