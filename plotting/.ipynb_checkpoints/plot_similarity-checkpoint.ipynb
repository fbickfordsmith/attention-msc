# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
/Users/fbickfordsmith/Google Drive/Project/attention/npy/mean_activations.npy

# %%
import os
os.listdir(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-70e9b53976db> in <module>
#       1 import os
# ----> 2 os.listdir(path)
#
# FileNotFoundError: [Errno 2] No such file or directory: '~/Google Drive/Project/'

# %%
path = '~/Google Drive/Project/'
activations = np.load(path+'attention/npy/mean_activations.npy')
# similarity = np.load(path+'attention/npy/cosine_similarity.npy')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-7e76140e99d9> in <module>
#       1 path = '~/Google Drive/Project/'
# ----> 2 activations = np.load(path+'attention/npy/mean_activations.npy')
#       3 # similarity = np.load(path+'attention/npy/cosine_similarity.npy')
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     382     own_fid = False
#     383     if isinstance(file, basestring):
# --> 384         fid = open(file, "rb")
#     385         own_fid = True
#     386     elif is_pathlib_path(file):
#
# FileNotFoundError: [Errno 2] No such file or directory: '~/Google Drive/Project/attention/npy/mean_activations.npy'

# %%
activations.shape
# Out:
# (1000, 4096)

# %%
w, h = 20, 11
num_rows = 1000
num_cols = 4096 #int((w/h)*num_rows)
plt.figure(figsize=(w, h))
plt.imshow(activations[:num_rows, :num_cols])
plt.show()

# %%
plt.figure(figsize=(7, 7))
plt.imshow(similarity)
# plt.colorbar()
plt.show()
